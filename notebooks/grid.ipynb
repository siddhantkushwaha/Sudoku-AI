# %%
import cv2 as cv
import matplotlib.pyplot as plt

from clean import clean

# %%
path = '../data/train/image1083.jpg'
image = cv.cvtColor(cv.imread(path), cv.COLOR_BGR2RGB)

plt.imshow(image)

# %%
cleaned, _= clean(image)
plt.imshow(cleaned)

# %%
cv.imwrite('../data/ref_sudoku.jpg', cleaned)
# Out:
# True
